# %% [markdown]
# **Nesne Yönelimli Programlama (Object Oriented Programming)**

# %% [markdown]
# OOP temel olarak, ortaya çıktığı güne kadar süregelen programlama mantığını kökten değiştirmiştir. OOP’den önce kullanılan yazılım metodolojisi, Prosedürel Programlama adı ile anılır. Bu metodoloji, belirli bir yönde ilerleyen kodlar ve iş yükünü hafifletmek için ortak işlerin yüklendiği fonksiyonların çağırılması esasına dayalıydı
# ![image.png](attachment:image.png)

# %% [markdown]
# Bu metodoloji, yazılım dünyasının uzun süre işini görse de, bazı sıkıntıları da içinde barındırıyordu:
#
# =>Geliştirilen uygulama parçalanamayan bir bütün halindeydi. Bu yüzden, uygulama üzerinde çalışan her geliştirici; uygulamanın hemen her yapısına hakim olmalıydı.
#
# =>Bu durum nedeniyle, projelere yeni yazılımcıların katılması önemli bir adaptasyon süreci gerektiriyordu.
# =>Uygulama tek bir bütün halinde olduğu için, ufak değişiklikler uygulamanın farklı noktalarında büyük sorunlara yol açabiliyordu.
#
# =>Yıllarla birlikte müşteri ihtiyaçları ve donanım kabiliyetleri arttı. Bunun getirisi olarak da, geliştirilen uygulamaların kapsamları ve boyutları büyüdü. Bu aşamada, yukarıda bahsedilen problemler gittikçe artmaya başladı. Başlanan projelerin çoğu istenen sürelerde yetiştirilememeye ve geliştirme zorluklarından ötürü iptal olmaya başladı.
# Uygulama maliyetleri giderek artmaya başladı.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Yazılım dünyasında bu çıkmazın aşılması OOP ile sağlanmıştır. OOP ile tüm yazılım anlayışı kökten değişmiştir.
#
# =>Uygulama, nesneler ve onların ilişkileri çerçevesinde belirli bir iş yapmak için geliştirilebilmelidir.
#
# =>Her nesnenin bir sınıfı olmalıdır ve sınıflar nesnelerin ortak davranışlarını ifade etmelidir.
#
# =>Nesneler birbirleri ile iletişime geçebilmelidir.
#
# Bunu basitçe, prosedürel programlamada bulunan soyut program geliştirme mantığını rafa kaldırıp, gerçek dünya modellemesi ile program geliştirme çabası olarak da düşünebiliriz. Gerçek dünya modellemesiyle anlatılmak istenen şudur: Bir fabrika örneğini ele alalım. Bu fabrikada işçiler, makineler gibi birçok nesne bulunur ve bu nesnelerin ilişkisi çerçevesinde fabrika çeşitli işler yapıp çıktılar üretebilir. OOP ile programlama mantığında da, bu örnektekine benzer şekilde program kurgulanır. Çeşitli nesneler geliştirilip birbirleriyle ilişkilendirilerek, belirli amaçlara hizmet eden uygulamalar geliştirilir.
#
# Bu yapının önemli getirileri şunlardır: Yazacağınız sınıflar birbirinden bağımsız olarak geliştirilebilir. Bu sayede program böl, parçala, fethet mantığı çerçevesinde çok kolay bir şekilde parçalanır ve her parça ayrı ayrı ele alınabilir. OOP mantığında gerçek dünya algılayışı temel alındığı için bu, anlaşılması çok daha kolay bir yapıdır.
#
# OOP, yapısı gereği kod tekrarlarının önüne geçer (doğru bir şekilde kullanılırsa) ve bu durum, özellikle ilk dönemlerde yazılımcıların hızlı bir şekilde OOP yapılarına geçmesinin temel nedenlerinden biri olmuştur.
#
# Yukarıda değinilen getiriler, projelerin yönetilebilirliğini büyük miktarda artırdığı için daha büyük projeler çok daha az çaba ile yönetilebilir hale gelmiştir. Yine aynı getiriler sayesinde, projeler rahat bir şekilde büyütülebilmiştir. Alttaki grafikte noktalı çizgilerle gösterilen bölümler OOP’nin etkileridir. Yani, OOP ile yazılım kalitesi artmış, bunun yanısıra yazılım maliyetleri düşmüştür.
#
# Not: Bu kısma kadar olan tanımlamalarda Türkcell geleceği yazanlar C Sharp uygulama geliştirme sayfasından faydalanılmıştır.
# https://gelecegiyazanlar.turkcell.com.tr/konu/c-sharp/egitim/101
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Class(Sınıf) Mantığı:**
# Class sınıfımızın özelliklerini ve yapabileceklerini(method) tanımlayan bir methoddur.
#
# ![image.png](attachment:image.png)

# %%
class Personel():
    sicil ="123"
    ad ="Yasin"
    soyad ="Gürbüz"
    bolum ="Mekatronik"

# %%
per1 = Personel()
print(per1.ad)
print(per1.soyad)

# %%
per2= Personel()
print(per1.ad)
print(per2.soyad)

# %% [markdown]
# Burada per1 ve per2 nesnelerimizin ikisinde de aynı değerleri aldık çünkü bu özellikler birer sınıf özellikleridir. Yani bir sınıf oluşturduğumuzda bu değerler varsayılan olarak gelir.

# %% [markdown]
# Her nesnemizi farklı değerlerle oluşturmak istersek __init__ fonksiyonunu kullanıyoruz. init fonksiyonu pythonda yapıcı(constructor) metodur. Yanı nesne tanımlandığında bu fonksiyon çalışır.

# %%
class Personel():
    def __init__(self):
        print("Personel sınıfı init metodu çaılıştı!!")

per1 = Personel()

# %% [markdown]
# **Self Parametresi**
# self anahtar kelimesi objeyi oluşturduğumuz zaman o objeyi gösteren bir referanstır ve metodlarımızda en başta bulunması gerekmektedir. Objeler oluşturulurken python referans olarak kendi gönderir yani biz nesnelerimizi tanımlarken self parametresine değer göndermeyiz bunu bizim için python otamatik olarak yapar. Self referansı sayesinde nesnemizin tüm metod ve özelliklerine ulaşabiliriz.

# %%
 class Personel():
    def __init__(self,sicil,ad,soyad,maas,birim):
        print("Personel sınıfı init çaılıştı")
        self.sicil = sicil
        self.ad = ad
        self.soyad = soyad
        self.maas = maas
        self.birim = birim
        
    def bilgiler(self):
        print("Sicil: {}, Ad: {}, Soyad: {}, Maas: {}, Birim:{}".format(self.sicil,self.ad, self.soyad,self.maas,self.birim))
    
    def zamYap(self,tutar):
        self.maas += tutar #self.maas = self.maas

# %%
per1 = Personel("123","Yasin","GÜRBÜZ",5000,"İD")
per1.bilgiler()

# %%
per1.zamYap(100)

# %%
per1.bilgiler()

# %% [markdown]
# **Kalıtım (Inheritance)**
# Kalıtım bir sınıfın başka bir sınıftan özellik(attribute) ve metodlarını miras almasıdır.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Personel():
    def __init__(self,sicil,ad,soyad,maas,birim):
        print("Personel sınıfı init çaılıştı")
        self.sicil = sicil
        self.ad = ad
        self.soyad = soyad
        self.maas = maas
        self.birim = birim
        
    def bilgiler(self):
        print("Sicil: {}, Ad: {}, Soyad: {}, Maas: {}, Birim:{}".format(self.sicil,self.ad, self.soyad,self.maas,self.birim))
    
    def zamYap(self,tutar):
        self.maas += tutar #self.maas = self.maas
        
    def birimDegis(self,yBr):
        self.birim= yBr 
        
class Yazilimci(Personel): #Burda Yazilimci sınıfını Personel sınıfından miras aldığımızı belirttik.
    pass #Bir bloğu sonradan tanımlamak istediğimiz zaman kullanılan bir deyimdir.

# %%
#Burada personel sınıfından miras aldığımız özellik ve methodları kullandık.
yazilimci1 = Yazilimci("123","İsmail","AYDIN",5000,"BL")
yazilimci1.bilgiler()
# Out:
# Personel sınıfı init çaılıştı
# Sicil: 123, Ad: İsmail, Soyad: AYDIN, Maas: 5000, Birim:BL

# %% [markdown]
# **Overriding (İptal Etme)**
# Miras aldığımız sınıfta mevcut bir metodu kendi sınıfımızda da tanımlarsak metodu çağırdığımızda artık kendi sınıfımızdaki metod çalışacaktır. Bu kavrama nesne tabanlı programlamada methodu override etmek denir.

# %%
class Personel():
    def __init__(self,sicil,ad,soyad,maas,birim):
        print("Personel sınıfı init çaılıştı")
        self.sicil = sicil
        self.ad = ad
        self.soyad = soyad
        self.maas = maas
        self.birim = birim
        
    def bilgiler(self):
        print("Sicil: {}, Ad: {}, Soyad: {}, Maas: {}, Birim:{}".format(self.sicil,self.ad, self.soyad,self.maas,self.birim))
    
    def zamYap(self,tutar):
        self.maas += tutar #self.maas = self.maas
        
    def birimDegis(self,yBr):
        self.birim= yBr 
        
class Yazilimci(Personel):
    #Yazilimci sınıfında da __init__ fonk tanımlayarak miras aldığımız sınıfın(Personel) init metodunu iptal ettik.
    #Artık yazılımcı sınıfından bir nesne türettiğimizde kendi init fonksiyonumuzu çalıştırdığımızı 
    #print ettiğimiz "Yazılmci init fonk" mesajından anlıyoruz.
    def __init__(self,sicil,ad,soyad,maas,birim,pDil):
        print("Yazılmci init fonk")
        self.sicil = sicil
        self.ad = ad
        self.soyad = soyad
        self.maas = maas
        self.birim = birim
        self.pDil = pDil
    def pDilEkle(self,pDil):
        self.pDil.append(pDil)
    def pDilListele(self):
        for i in self.pDil:
            print(i)

# %%
yazilimci1 = Yazilimci("123","İsmail","AYDIN",100,"BL",["c#","Python","Js"])
yazilimci1.bilgiler()
# Out:
# Yazılmci init fonk
# Sicil: 123, Ad: İsmail, Soyad: AYDIN, Maas: 100, Birim:BL

# %%
yazilimci1.pDilEkle("NodeJS")
yazilimci1.zamYap(5000)
yazilimci1.bilgiler()
yazilimci1.pDilListele()
# Out:
# Sicil: 123, Ad: İsmail, Soyad: AYDIN, Maas: 5100, Birim:BL
# c#
# Python
# Js
# NodeJS

# %% [markdown]
# **Super Anahtar Kelimesi**

# %% [markdown]
# Miras aldığımız metodları kendi metodlarımız içerisinde kullanabilmemizi sağlar.

# %%
class Personel():
    def __init__(self,sicil,ad,soyad,maas,birim):
        print("Personel sınıfı init çaılıştı")
        self.sicil = sicil
        self.ad = ad
        self.soyad = soyad
        self.maas = maas
        self.birim = birim
        
    def bilgiler(self):
        print("Sicil: {}, Ad: {}, Soyad: {}, Maas: {}, Birim:{}".format(self.sicil,self.ad, self.soyad,self.maas,self.birim))
    
    def zamYap(self,tutar):
        self.maas += tutar #self.maas = self.maas
        
    def birimDegis(self,yBr):
        self.birim= yBr 
        
class Yazilimci(Personel):
    def __init__(self,sicil,ad,soyad,maas,birim,pDil):
        print("Yazılmci init fonk")
        super().__init__(sicil,ad,soyad,maas,birim)
        self.pDil = pDil
    def pDilEkle(self,pDil):
        self.pDil.append(pDil)
    def pDilListele(self):
        for i in self.pDil:
            print(i)

# %%
yazilimci1 = Yazilimci("123","İsmail","AYDIN",100,"BL",["c#","Python","Js"])
yazilimci1.zamYap(5000)
yazilimci1.pDilEkle("NodeJS")
yazilimci1.bilgiler()
yazilimci1.pDilListele()
# Out:
# Yazılmci init fonk
# Personel sınıfı init çaılıştı
# Sicil: 123, Ad: İsmail, Soyad: AYDIN, Maas: 5100, Birim:BL
# c#
# Python
# Js
# NodeJS

# %% [markdown]
# **ÖZEL METODLAR**

# %% [markdown]
# **1) str Metodu**

# %%
class Kitap():
    def __init__(self,kAd,yazar,sfSay):
        self.kAd = kAd
        self.yazar = yazar
        self.sfSay = sfSay    
kitap = Kitap("Beyaz Gimi","Cengiz AYTMATOV",168)
print(kitap)#nesnemizi print ettiğmizde bir mesaj yazdırmak için kullanırız.

# %%
class Kitap():
    def __init__(self,kAd,yazar,sfSay):
        self.kAd = kAd
        self.yazar = yazar
        self.sfSay = sfSay 
    def __str__(self):
        return "Kitap Adı: {}, Yazar: {}".format(self.kAd, self.yazar)
kitap = Kitap("Beyaz Gimi","Cengiz AYTMATOV",168)
print(kitap)
# Out:
# Kitap Adı: Beyaz Gimi, Yazar: Cengiz AYTMATOV

# %% [markdown]
# **2) len Metodu**

# %%
class Kitap():
    def __init__(self,kAd,yazar,sfSay):
        self.kAd = kAd
        self.yazar = yazar
        self.sfSay = sfSay 
    def __len__(self):
        return self.sfSay
kitap = Kitap("Beyaz Gimi","Cengiz AYTMATOV",168)

# %%
print(len(kitap))
# Out:
# 168

# %% [markdown]
# **3) del Metodu**
#
# del metodu bir nesneyi del anahtar kelimesi ile sildiğimizde çalışır.

# %%
class Kitap():
    def __init__(self,kAd,yazar,sfSay):
        self.kAd = kAd
        self.yazar = yazar
        self.sfSay = sfSay
    def __str__(self):
        return "Kitap Adı: {}, Yazar: {}".format(self.kAd, self.yazar)
    def __len__(self):
        return self.sfSay
    def __del__(self):
        print("Nesne silindi")

# %%
kitap = Kitap("Beyaz Gemi","Cengiz ..", 300)

# %%
print(kitap)
# Out:
# Kitap Adı: Beyaz Gemi, Yazar: Cengiz ..

# %%
del kitap
# Out:
# Nesne silindi

# %%
print(kitap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6dabb6e25b27> in <module>
# ----> 1 print(kitap)
#
# NameError: name 'kitap' is not defined

# %% [markdown]
# **Nesne Listesi Örneği**

# %%
class Personel():
    def __init__(self,tc,ad="boş",soyad="boş"):
        self.tc = tc
        self.ad = ad
        self.soyad = soyad

# %%
print("""
q => çıkış
y => yeni personel
""")
personeller = list()
while(True):
    islem = input("Yapmak istediğiniz islem(q/y) :")
    if(islem=="y"):
        tc = input("tc")
        if(len(tc)==0):#aynı tc daha önce girilmiş mi kontrolü
            print("Tc alanı boş bırakılamaz !!")
            continue
        else:
            ad = input("Ad: ")
            soyad = input("Soyad: ")
            per = Personel(tc,ad,soyad)
            personeller.append(per)
    elif(islem=="q"):
        print("Bye bye..")
        break
    else:
        print("Hatalı giriş!!")

for per in personeller:
    print("Tc: {}, Ad: {}, Soyad: {}".format(per.tc,per.ad,per.soyad))
# Out:
# q => çıkış
# y => yeni personel
#
# Yapmak istediğiniz islem(q/y) :y
# tc123
# adismail
# soyadaydın
# Yapmak istediğiniz islem(q/y) :q
# Bye bye..
# Tc: 123, Ad: ismail, Soyad: aydın
